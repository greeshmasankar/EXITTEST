# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Obesity.csv')
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2102 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2101 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2105 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2102 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2104 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Gender                             9
# Age                                0
# Height                            10
# Weight                             0
# family_history_with_overweight     6
# FAVC                               0
# FCVC                               0
# NCP                                0
# CAEC                               9
# SMOKE                              0
# CH2O                               0
# SCC                                7
# FAF                                0
# TUE                                0
# CALC                               0
# MTRANS                             7
# NObeyesdad                         0
# dtype: int64

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2101.000000  2111.000000  2111.000000  2111.000000
# mean     24.488346     1.701995    86.586058     2.419043     2.685628
# std       7.365358     0.093288    26.191172     0.533927     0.778039
# min       2.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.804818     1.701284    83.000000     2.385502     3.000000
# 75%      26.000000     1.768834   107.430682     3.000000     3.000000
# max      99.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Weight'}>],
#        [<Axes: title={'center': 'FCVC'}>,
#         <Axes: title={'center': 'NCP'}>,
#         <Axes: title={'center': 'CH2O'}>],
#        [<Axes: title={'center': 'FAF'}>, <Axes: title={'center': 'TUE'}>,
#         <Axes: >]], dtype=object)

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['family_history_with_overweight']=df['family_history_with_overweight'].fillna(df['family_history_with_overweight'].mode()[0])
df['CAEC']=df['CAEC'].fillna(df['CAEC'].mode()[0])
df['SCC']=df['SCC'].fillna(df['SCC'].mode()[0])
df['MTRANS']=df['MTRANS'].fillna(df['MTRANS'].mode()[0])
df['Height']=df['Height'].fillna(df['Height'].mean())
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.value_counts("Gender")
# Out:
# Gender
# Male      1070
# Female    1041
# Name: count, dtype: int64

# %%
df.value_counts("family_history_with_overweight")
# Out:
# family_history_with_overweight
# yes    1728
# no      383
# Name: count, dtype: int64

# %%
df.value_counts("CAEC")
# Out:
# CAEC
# Sometimes     1767
# Frequently     241
# Always          53
# no              50
# Name: count, dtype: int64

# %%
df.value_counts("SCC")
# Out:
# SCC
# no     2015
# yes      96
# Name: count, dtype: int64

# %%
df.value_counts("MTRANS")
# Out:
# MTRANS
# Public_Transportation    1583
# Automobile                455
# Walking                    55
# Motorbike                  11
# Bike                        7
# Name: count, dtype: int64

# %%
df.value_counts("CALC")
# Out:
# CALC
# Sometimes     1401
# no             639
# Frequently      70
# Always           1
# Name: count, dtype: int64

# %%
df.value_counts("NObeyesdad")
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
#plot bar chart between gender and nobeyesdad
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',hue='NObeyesdad',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in ['Gender', 'family_history_with_overweight', 'CAEC', 'SCC', 'MTRANS', 'CALC', 'FAVC','SMOKE','NObeyesdad']:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1     0   2.0
# 1       0  21.0    1.52    56.0                               1     0   3.0
# 2       1  23.0    1.80    77.0                               1     0   2.0
# 3       1  27.0    1.80    87.0                               0     0   3.0
# 4       1  22.0    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# 0  3.0     2      0   2.0    0  0.0  1.0     3       3           1
# 1  3.0     2      1   3.0    1  3.0  0.0     2       3           1
# 2  3.0     2      0   2.0    0  2.0  1.0     1       3           1
# 3  3.0     2      0   2.0    0  2.0  0.0     1       4           5
# 4  1.0     2      0   2.0    0  0.0  0.0     2       3           6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   int64
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   int64
#  5   FAVC                            2111 non-null   int64
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   int64
#  9   SMOKE                           2111 non-null   int64
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   int64
# ...

# %%
df.corr()
# Out:
#                                   Gender       Age    Height    Weight  \
# Gender                          1.000000  0.032989  0.616895  0.159603
# Age                             0.032989  1.000000 -0.039338  0.155285
# Height                          0.616895 -0.039338  1.000000  0.459837
# Weight                          0.159603  0.155285  0.459837  1.000000
# family_history_with_overweight  0.106044  0.144507  0.244199  0.495331
# FAVC                            0.065622  0.023134  0.175955  0.272300
# FCVC                           -0.274224  0.024224 -0.038149  0.216125
# NCP                             0.065931 -0.053689  0.244613  0.107469
# CAEC                            0.090287  0.056092  0.048289  0.287923
# SMOKE                           0.044423  0.075774  0.055144  0.025746
# CH2O                            0.109454 -0.031157  0.213295  0.200575
# SCC                            -0.103050 -0.105398 -0.133080 -0.201906
# ...

# %%
fig,ax=plt.subplots(figsize=(10,10))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',ax=ax)
plt.show()

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1     0   2.0
# 1       0  21.0    1.52    56.0                               1     0   3.0
# 2       1  23.0    1.80    77.0                               1     0   2.0
# 3       1  27.0    1.80    87.0                               0     0   3.0
# 4       1  22.0    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# 0  3.0     2      0   2.0    0  0.0  1.0     3       3           1
# 1  3.0     2      1   3.0    1  3.0  0.0     2       3           1
# 2  3.0     2      0   2.0    0  2.0  1.0     1       3           1
# 3  3.0     2      0   2.0    0  2.0  0.0     1       4           5
# 4  1.0     2      0   2.0    0  0.0  0.0     2       3           6

# %%
df.drop(['FAVC', 'FCVC', 'NCP', 'SMOKE', 'CH2O', 'SCC', 'FAF','CAEC', 'TUE','CALC','MTRANS'],axis=1,inplace=True)

# %%
fig,ax=plt.subplots(figsize=(10,10))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
#handle outliers using IQR
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
#scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df[['Age','Height','Weight']]=scaler.fit_transform(df[['Age','Height','Weight']])
df
# Out:
#       Gender       Age    Height    Weight  family_history_with_overweight  \
# 0          0 -0.571115 -1.132917 -1.185724                               1
# 1          0 -0.571115 -2.289536 -1.509744                               1
# 2          1 -0.109340  0.948998 -0.659192                               1
# 6          0 -0.109340 -2.520860 -1.550247                               1
# 8          1  0.121548  0.717675 -1.185724                               1
# ...      ...       ...       ...       ...                             ...
# 2106       0 -0.576462 -0.083516  1.544491                               1
# 2107       0 -0.344166  0.354311  1.639040                               1
# 2108       0 -0.219234  0.396204  1.636870                               1
# 2109       0  0.205115  0.248665  1.622989                               1
# 2110       0  0.044134  0.241564  1.628092                               1
#
#       NObeyesdad
# 0              1
# 1              1
# ...

# %%
y=df['NObeyesdad']
x=df.drop('NObeyesdad',axis=1)

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1255, 5), (314, 5), (1255,), (314,))

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
#descion tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9394904458598726

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[26,  4,  0,  0,  0,  0,  0],
#        [ 4, 23,  0,  0,  0,  0,  0],
#        [ 0,  0, 55,  1,  0,  0,  0],
#        [ 0,  0,  1, 58,  0,  0,  0],
#        [ 0,  0,  0,  0, 58,  0,  0],
#        [ 0,  2,  0,  0,  0, 29,  4],
#        [ 0,  0,  0,  0,  0,  3, 46]])

# %%
precision_score(y_test,y_pred,average='weighted')
# Out:
# 0.9401673347243577

# %%
f1_score(y_test,y_pred,average='weighted')
# Out:
# 0.939530039575196

# %%
recall_score(y_test,y_pred,average='weighted')
# Out:
# 0.9394904458598726

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.964968152866242

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[29,  1,  0,  0,  0,  0,  0],
#        [ 2, 24,  0,  0,  0,  1,  0],
#        [ 0,  0, 56,  0,  0,  0,  0],
#        [ 0,  0,  1, 58,  0,  0,  0],
#        [ 0,  0,  0,  0, 58,  0,  0],
#        [ 0,  0,  0,  0,  0, 31,  4],
#        [ 0,  1,  0,  0,  0,  1, 47]])

# %%
precision_score(y_test,y_pred,average='weighted')
# Out:
# 0.9650980494765738

# %%
f1_score(y_test,y_pred,average='weighted')
# Out:
# 0.964806803608228

# %%
recall_score(y_test,y_pred,average='weighted')
# Out:
# 0.964968152866242

# %%
#svm
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=svm.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9331210191082803

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9394904458598726

# %%
#print classification report of KNN
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85        30
#            1       0.82      0.67      0.73        27
#            2       0.98      1.00      0.99        56
#            3       1.00      0.98      0.99        59
#            4       1.00      1.00      1.00        58
#            5       0.80      0.94      0.87        35
#            6       0.96      0.96      0.96        49
#
#     accuracy                           0.94       314
#    macro avg       0.92      0.91      0.91       314
# weighted avg       0.94      0.94      0.94       314

# %%
from sklearn.model_selection import GridSearchCV



# Define hyperparameters and their possible values
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Perform grid search
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best hyperparameters:", best_params)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
